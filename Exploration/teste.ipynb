# %%
import matplotlib.pyplot as plt
import numpy as np
a=[1,2,3,4,5,6,7,8]
plt.plot(a)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
## milk
import matplotlib.pyplot as plt

bac=1.5e6
tim = 0

while bac<=10000000:
    
    bac *= 1.5
    tim += 1

    print(tim)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
import pandas as pd
a=(1,23,4,5,6,5,3,4,5,5)
b=list(a)
pd.DataFrame(b)
plt.plot(a)
plt.show
plt.show(close=1, block=2)
